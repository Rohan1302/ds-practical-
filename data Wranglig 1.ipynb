# %%
import pandas as pd
import numpy as np

# %%
Data1 = pd.read_csv('AcademicPerformance.csv')

# %%
Data1
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04       NaN
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3      NaN          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
Data1.isnull().sum()
# Out:
# gender                      10
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    6
# Topic                        0
# Semester                     9
# Relation                     0
# raisedhands                 10
# VisITedResources             5
# AnnouncementsView            4
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
Data1.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
Data1.shape
# Out:
# (480, 17)

# %%
Data1.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   470.000000        475.000000         476.000000  480.000000
# mean     47.506383         55.374737          38.237395   43.283333
# std      30.483226         32.769213          26.493621   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      17.000000         20.000000          15.000000   20.000000
# 50%      50.000000         66.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
Data1.head(5)
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04       NaN    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3    NaN          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father         15.0              16.0                2.0
# 1        F   Father         20.0              20.0                3.0
# 2      NaN   Father         10.0               7.0                0.0
# 3        F   Father         30.0              25.0                5.0
# 4        F   Father         40.0              50.0               12.0
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
Data1.drop('gender', axis=1)
# Out:
#     NationalITy PlaceofBirth       StageID GradeID SectionID      Topic  \
# 0            KW       KuwaIT    lowerlevel    G-04         A         IT
# 1            KW       KuwaIT    lowerlevel    G-04       NaN         IT
# 2            KW       KuwaIT    lowerlevel    G-04         A         IT
# 3            KW       KuwaIT    lowerlevel    G-04         A         IT
# 4            KW       KuwaIT    lowerlevel    G-04         A         IT
# ..          ...          ...           ...     ...       ...        ...
# 475      Jordan       Jordan  MiddleSchool    G-08         A  Chemistry
# 476      Jordan       Jordan  MiddleSchool    G-08         A    Geology
# 477      Jordan       Jordan  MiddleSchool    G-08         A    Geology
# 478      Jordan       Jordan  MiddleSchool    G-08         A    History
# 479      Jordan       Jordan  MiddleSchool    G-08         A    History
#
#     Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# ...

# %%
Data1.iloc[0:3,0:5]
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID
# 0      M          KW       KuwaIT  lowerlevel    G-04
# 1      M          KW       KuwaIT  lowerlevel    G-04
# 2      M          KW       KuwaIT  lowerlevel    G-04

# %%
Data1['gender']
Data1.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
Data1.dropna(inplace=True)
Data1.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
Data1['raisedhands'] = Data1['raisedhands'].replace(np.NaN,Data1['raisedhands'].mean())
Data1['raisedhands']
# Out:
# 0      15.0
# 4      40.0
# 7      50.0
# 8      12.0
# 10     50.0
#        ...
# 475     5.0
# 476    50.0
# 477    55.0
# 478    30.0
# 479    35.0
# Name: raisedhands, Length: 444, dtype: float64

# %%
Data1['pr'] = Data1['raisedhands']/2
Data1['pr']
# Out:
# 0       7.5
# 4      20.0
# 7      25.0
# 8       6.0
# 10     25.0
#        ...
# 475     2.5
# 476    25.0
# 477    27.5
# 478    15.0
# 479    17.5
# Name: pr, Length: 444, dtype: float64

# %%
list1 = ["A","B","C","C","A","A"]
list1 = list(dict.fromkeys(list1))

# %%
list1
# Out:
# ['A', 'B', 'C']

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 444 entries, 0 to 479
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    444 non-null    object
#  1   NationalITy               444 non-null    object
#  2   PlaceofBirth              444 non-null    object
#  3   StageID                   444 non-null    object
#  4   GradeID                   444 non-null    object
#  5   SectionID                 444 non-null    object
#  6   Topic                     444 non-null    object
#  7   Semester                  444 non-null    object
#  8   Relation                  444 non-null    object
#  9   raisedhands               444 non-null    float64
#  10  VisITedResources          444 non-null    float64
#  11  AnnouncementsView         444 non-null    float64
#  12  Discussion                444 non-null    int64
# ...
